# %%
import matplotlib.pyplot as plt
#import matplotlib.image as mpimg
#import numpy as np
#import random
from skimage import io
from skimage import color
#from skimage import data
#%matplotlib inline

#from scipy import misc,ndimage
#l = misc.lena()
#misc.imsave('lena.png', l)
#lena = misc.imread('lena.png')
#lena.shape, lena.dtype
#plt.imshow(lena, cmap=plt.cm.gray)

#I=io.imread('../../windows_share/sandbox/zP5xF.jpg')
I=io.imread('puzzle1_400dpi.tif')

# %%
print(I[0,0])

#io.find_available_plugins() #
#plt.ioff()
#plt.plot(I)
#plt.draw()
#print plt.rcParams
plt.rcParams['figure.figsize'] = (18,12)
#plt.imshow(I)
#I.shape
# Out:
# [255   5 174]

# %%
#img = data.astronaut()
#img_hsv = color.rgb2hsv(img)
#print(img[100,100])
#print(img_hsv[100,100])
#F=I.astype(float)/256.0

#print(F.size)
#p=F[3000,990]
#print(p)

F=I.astype(float)[500:1000,:1000,:]

print(F.size,F.shape)
#HSV=color.rgb2hsv(F)
#print(HSV.size)
# Out:
# (1500000, (500, 1000, 3))

# %%
G=F.astype('B')
print(G.shape)
print(G[0])
plt.imshow(G)
# Out:
# (500, 1000, 3)
# [[255   0 192]
#  [255   0 196]
#  [255   3 196]
#  ...
#  [255   8 159]
#  [255   0 156]
#  [255   0 163]]
